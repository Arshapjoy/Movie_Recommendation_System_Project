# %% [markdown]
# <a href="https://colab.research.google.com/github/Arshapjoy/Movie_Recommendation_System_Project/blob/main/notebooks/1_cleaning_preprocessing.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np

# %%
movies=pd.read_csv("/content/drive/MyDrive/MCA_project/Final/rotten_tomatoes_movies.csv")

# %%
reviews=pd.read_csv("/content/drive/MyDrive/MCA_project/Final/rotten_tomatoes_movie_reviews.csv")

# %%
movies.head()
# Out:
#                      id                title  audienceScore  tomatoMeter  \
# 0    space-zombie-bingo  Space Zombie Bingo!           50.0          NaN
# 1       the_green_grass      The Green Grass            NaN          NaN
# 2             love_lies           Love, Lies           43.0          NaN
# 3  the_sore_losers_1997          Sore Losers           60.0          NaN
# 4  dinosaur_island_2002      Dinosaur Island           70.0          NaN
#
#   rating ratingContents releaseDateTheaters releaseDateStreaming  \
# 0    NaN            NaN                 NaN           2018-08-25
# 1    NaN            NaN                 NaN           2020-02-11
# 2    NaN            NaN                 NaN                  NaN
# 3    NaN            NaN                 NaN           2020-10-23
# 4    NaN            NaN                 NaN           2017-03-27
#
#    runtimeMinutes                          genre originalLanguage  \
# 0            75.0         Comedy, Horror, Sci-fi          English
# 1           114.0                          Drama          English
# 2           120.0                          Drama           Korean
# 3            90.0     Action, Mystery & thriller          English
# 4            80.0  Fantasy, Adventure, Animation          English
#
#                         director                                  writer  \
# 0                  George Ormrod              George Ormrod,John Sabotta
# 1                Tiffany Edwards                         Tiffany Edwards
# 2  Park Heung-Sik,Heung-Sik Park  Ha Young-Joon,Jeon Yun-su,Song Hye-jin
# 3          John Michael McCarthy                   John Michael McCarthy
# 4                  Will Meugniot                                John Loy
#
#   boxOffice distributor soundMix
# 0       NaN         NaN      NaN
# 1       NaN         NaN      NaN
# 2       NaN         NaN      NaN
# 3       NaN         NaN      NaN
# 4       NaN         NaN      NaN

# %%
reviews.head()
# Out:
#                                   id  reviewId creationDate       criticName  \
# 0                            beavers   1145982   2003-05-23  Ivan M. Lincoln
# 1                         blood_mask   1636744   2007-06-02    The Foywonder
# 2  city_hunter_shinjuku_private_eyes   2590987   2019-05-28     Reuben Baron
# 3  city_hunter_shinjuku_private_eyes   2558908   2019-02-14      Matt Schley
# 4                 dangerous_men_2015   2504681   2018-08-29        Pat Padua
#
#    isTopCritic originalScore reviewState                 publicatioName  \
# 0        False         3.5/4       fresh  Deseret News (Salt Lake City)
# 1        False           1/5      rotten                  Dread Central
# 2        False           NaN       fresh                            CBR
# 3        False         2.5/5      rotten                    Japan Times
# 4        False           NaN       fresh                          DCist
#
#                                           reviewText scoreSentiment  \
# 0  Timed to be just long enough for most youngste...       POSITIVE
# 1  It doesn't matter if a movie costs 300 million...       NEGATIVE
# 2  The choreography is so precise and lifelike at...       POSITIVE
# 3  The film's out-of-touch attempts at humor may ...       NEGATIVE
# 4  Its clumsy determination is endearing and some...       POSITIVE
#
#                                            reviewUrl
# 0  http://www.deseretnews.com/article/700003233/B...
# 1  http://www.dreadcentral.com/index.php?name=Rev...
# 2  https://www.cbr.com/city-hunter-shinjuku-priva...
# 3  https://www.japantimes.co.jp/culture/2019/02/0...
# 4  http://dcist.com/2015/11/out_of_frame_dangerou...

# %%
movies.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 143258 entries, 0 to 143257
# Data columns (total 16 columns):
#  #   Column                Non-Null Count   Dtype
# ---  ------                --------------   -----
#  0   id                    143258 non-null  object
#  1   title                 142891 non-null  object
#  2   audienceScore         73248 non-null   float64
#  3   tomatoMeter           33877 non-null   float64
#  4   rating                13991 non-null   object
#  5   ratingContents        13991 non-null   object
#  6   releaseDateTheaters   30773 non-null   object
#  7   releaseDateStreaming  79420 non-null   object
#  8   runtimeMinutes        129431 non-null  float64
#  9   genre                 132175 non-null  object
#  10  originalLanguage      129400 non-null  object
#  11  director              139041 non-null  object
#  12  writer                90116 non-null   object
#  13  boxOffice             14743 non-null   object
#  14  distributor           23001 non-null   object
#  15  soundMix              15917 non-null   object
# dtypes: float64(3), object(13)
# memory usage: 17.5+ MB

# %%
reviews.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1444963 entries, 0 to 1444962
# Data columns (total 11 columns):
#  #   Column          Non-Null Count    Dtype
# ---  ------          --------------    -----
#  0   id              1444963 non-null  object
#  1   reviewId        1444963 non-null  int64
#  2   creationDate    1444963 non-null  object
#  3   criticName      1444963 non-null  object
#  4   isTopCritic     1444963 non-null  bool
#  5   originalScore   1009745 non-null  object
#  6   reviewState     1444963 non-null  object
#  7   publicatioName  1444963 non-null  object
#  8   reviewText      1375738 non-null  object
#  9   scoreSentiment  1444963 non-null  object
#  10  reviewUrl       1234038 non-null  object
# dtypes: bool(1), int64(1), object(9)
# memory usage: 111.6+ MB

# %%
print(movies.shape)
print(reviews.shape)
# Out:
# (143258, 16)
# (1444963, 11)

# %%
total=len(movies["id"])

# %%
len(movies["title"])
# Out:
# 143258

# %%
unique=len(movies["id"].unique())

# %%
total-unique

# %%
movies.isnull().sum()
# Out:
# id                           0
# title                      367
# audienceScore            70010
# tomatoMeter             109381
# rating                  129267
# ratingContents          129267
# releaseDateTheaters     112485
# releaseDateStreaming     63838
# runtimeMinutes           13827
# genre                    11083
# originalLanguage         13858
# director                  4217
# writer                   53142
# boxOffice               128515
# distributor             120257
# soundMix                127341
# dtype: int64

# %%
movies.duplicated().count()
# Out:
# 143258

# %%
import pandas as pd

# Load the dataset
movies_df = pd.read_csv("/content/drive/MyDrive/MCA_project/Final/rotten_tomatoes_movies.csv")

# Filter rows with duplicated titles
duplicated_titles_df = movies_df[movies_df.duplicated('title', keep=False)]

# Display the DataFrame with duplicated titles
duplicated_titles_df.head()
# Out:
#                                   id                     title  audienceScore  \
# 4               dinosaur_island_2002           Dinosaur Island           70.0
# 5                        adrift_2018                    Adrift           65.0
# 8                         sundowning                Sundowning            NaN
# 10  1015331-number_one_with_a_bullet  Number One With a Bullet           19.0
# 15                         daag_1973                 The Stain           82.0
#
#     tomatoMeter rating                                     ratingContents  \
# 4           NaN    NaN                                                NaN
# 5          69.0  PG-13  ['Injury Images', 'Brief Drug Use', 'Thematic ...
# 8           NaN    NaN                                                NaN
# 10          NaN    NaN                                                NaN
# 15          NaN    NaN                                                NaN
#
#    releaseDateTheaters releaseDateStreaming  runtimeMinutes  \
# 4                  NaN           2017-03-27            80.0
# 5           2018-06-01           2018-08-21           120.0
# 8                  NaN                  NaN           123.0
# 10                 NaN           2012-03-13           103.0
# 15                 NaN           2003-11-25           146.0
#
#                             genre originalLanguage           director  \
# 4   Fantasy, Adventure, Animation          English      Will Meugniot
# 5       Adventure, Drama, Romance          English  Baltasar Kormákur
# 8                           Drama          English     Jim Comas Cole
# 10                   Crime, Drama          English        Jack Smight
# 15                          Drama            Hindi        Yash Chopra
#
#                                               writer boxOffice distributor  \
# 4                                           John Loy       NaN         NaN
# 5   Aaron Kandell,Jordan Kandell,David Branson Smith    $31.4M   STX Films
# 8                                                NaN       NaN         NaN
# 10                                               NaN       NaN         NaN
# 15                         Yash Chopra,Gulshan Nanda       NaN         NaN
#
#    soundMix
# 4       NaN
# 5       NaN
# 8       NaN
# 10      NaN
# 15      NaN

# %%
combined_df = pd.merge(movies, reviews, on='id', how='outer')

# %%
combined_df.head()
# Out:
#                      id                title  audienceScore  tomatoMeter  \
# 0    space-zombie-bingo  Space Zombie Bingo!           50.0          NaN
# 1       the_green_grass      The Green Grass            NaN          NaN
# 2             love_lies           Love, Lies           43.0          NaN
# 3             love_lies           Love, Lies           43.0          NaN
# 4  the_sore_losers_1997          Sore Losers           60.0          NaN
#
#   rating ratingContents releaseDateTheaters releaseDateStreaming  \
# 0    NaN            NaN                 NaN           2018-08-25
# 1    NaN            NaN                 NaN           2020-02-11
# 2    NaN            NaN                 NaN                  NaN
# 3    NaN            NaN                 NaN                  NaN
# 4    NaN            NaN                 NaN           2020-10-23
#
#    runtimeMinutes                       genre  ...   reviewId creationDate  \
# 0            75.0      Comedy, Horror, Sci-fi  ...        NaN          NaN
# 1           114.0                       Drama  ...        NaN          NaN
# 2           120.0                       Drama  ...  2739073.0   2020-10-31
# 3           120.0                       Drama  ...  2333658.0   2016-06-15
# 4            90.0  Action, Mystery & thriller  ...        NaN          NaN
#
#     criticName isTopCritic originalScore reviewState     publicatioName  \
# 0          NaN         NaN           NaN         NaN                NaN
# 1          NaN         NaN           NaN         NaN                NaN
# 2  James Mudge       False           4/5       fresh   easternKicks.com
# 3   Diva Velez       False         3.5/5       fresh  TheDivaReview.com
# 4          NaN         NaN           NaN         NaN                NaN
#
#                                           reviewText scoreSentiment  \
# 0                                                NaN            NaN
# 1                                                NaN            NaN
# 2  Though let down by its routine love triangle n...       POSITIVE
# 3  While not perfect, Love, Lies is a worthy disc...       POSITIVE
# 4                                                NaN            NaN
#
#                                            reviewUrl
# 0                                                NaN
# 1                                                NaN
# 2     https://www.easternkicks.com/reviews/love-lies
# 3  http://thedivareview.com/Love_Lies_Movie_Revie...
# 4                                                NaN
#
# [5 rows x 26 columns]

# %%
combined_df.duplicated().sum()
# Out:
# 37720

# %%
combined_df.duplicated().sum()
# Out:
# 37720

# %%
combined_df.drop_duplicates(inplace=True)

# %%
missing_values_m = combined_df.isnull().sum()
missing_values_m
# Out:
# id                           0
# title                     5804
# audienceScore           118960
# tomatoMeter             142348
# rating                  636356
# ratingContents          636356
# releaseDateTheaters     345926
# releaseDateStreaming    151948
# runtimeMinutes           35485
# genre                    28102
# originalLanguage         35942
# director                 12226
# writer                  184248
# boxOffice               519871
# distributor             398075
# soundMix                815969
# reviewId                 72792
# creationDate             72792
# criticName               72792
# isTopCritic              72792
# originalScore           504225
# reviewState              72792
# publicatioName           72792
# reviewText              141487
# scoreSentiment           72792
# reviewUrl               281933
# dtype: int64

# %%
percentage_missing_m = (missing_values_m / len(combined_df)) * 100
print("Percentage of missing values:\n", percentage_missing_m)
# Out:
# Percentage of missing values:
#  id                       0.000000
# title                    0.385518
# audienceScore            7.901662
# tomatoMeter              9.455160
# rating                  42.268579
# ratingContents          42.268579
# releaseDateTheaters     22.977391
# releaseDateStreaming    10.092819
# runtimeMinutes           2.357015
# genre                    1.866615
# originalLanguage         2.387370
# director                 0.812086
# writer                  12.238277
# boxOffice               34.531314
# distributor             26.441276
# soundMix                54.198987
# reviewId                 4.835052
# creationDate             4.835052
# criticName               4.835052
# isTopCritic              4.835052
# originalScore           33.492062
# reviewState              4.835052
# publicatioName           4.835052
# reviewText               9.397970
# scoreSentiment           4.835052
# reviewUrl               18.726794
# dtype: float64

# %%
# Drop rows with missing values in the 'title' column
combined_df.dropna(subset=['title'], inplace=True)

# %%
# Columns to drop
columns_to_drop = ['releaseDateTheaters', 'releaseDateStreaming', 'boxOffice', 'soundMix','creationDate', 'criticName', 'isTopCritic', 'reviewState', 'publicatioName',  'reviewUrl']



# Drop columns
combined_df.drop(columns=columns_to_drop, inplace=True)

# %%
# Mean imputation for numerical columns
combined_df['audienceScore'].fillna(combined_df['audienceScore'].mean(), inplace=True)
combined_df['tomatoMeter'].fillna(combined_df['tomatoMeter'].mean(), inplace=True)
combined_df['runtimeMinutes'].fillna(combined_df['runtimeMinutes'].mean(), inplace=True)

# %%
combined_df['rating'].unique()
# Out:
# array([nan, 'PG-13', 'TVPG', 'R', 'PG', 'TV14', 'NC-17', 'TVG', 'TVMA',
#        'TVY7', 'G'], dtype=object)

# %%
# Columns for which 'Unknown' category needs to be created
columns_to_unknown_m = ['rating', 'ratingContents', 'genre', 'originalLanguage', 'director', 'writer', 'distributor','reviewText', 'scoreSentiment']


# Fill missing values with 'Unknown'
combined_df[columns_to_unknown_m] = combined_df[columns_to_unknown_m].fillna('Unknown')

# %%
combined_df['genre'].unique()
# Out:
# array(['Comedy, Horror, Sci-fi', 'Drama', 'Action, Mystery & thriller',
#        ..., 'Action, Comedy, Fantasy, Horror, Sci-fi',
#        'Fantasy, Horror, Mystery & thriller, Animation',
#        'Western, Comedy, Animation'], dtype=object)

# %%
unique=combined_df['originalScore'].unique().tolist()

# %%
print(unique)
# Out:
# [nan, '4/5', '3.5/5', '6/10', 'C+', '2/5', '3/5', '2.5/4.0', '2.5/4', '1.5/5', '2.5/5', '2/4', 'B-', '6.5/10', '3/10', '10/10', '3/4', 'B', 'C', 'C-', '1/5', '7/10', 'B+', '3.5/4.0', '3.5/4', '5/5', '8/10', '9/10', '5.85/10', '4/4', '1/4', '1.5/4', '4.0/5', '9.5/10', '2/10', '5.89431248/10', '5.5/10', 'D', '68/100', '0.5/4', 'F', '78/100', 'A-', '4.5/5', '85/100', '7.5/10', 'A', '5/10', '8.5/10', '.5/4', '0/4', '4/10', '13.20', '7.0/10', '8.7/10', '8.25/10', '20/100', 'D+', '1.5', '0/5', 'F-', '1', '1.5/10', '83/100', 'D-', '4.5/10', '60/100', 'C-plus', '2.0/4.0', '6.8/10', '35/100', '1.0/5.0', '2.1/2', '4.0/4.0', 'high +1 out of -4..+4', '70/100', '52/100', '48/100', '58/100', '65/100', '5.65/10', 'A+', '3.5', '90/100', 'ZERO STARS', '10/20', '4.5', '87/100', 'A-minus', '9.352969/10', '9.1/10', '39/100', '3/6', '4 of 5', 'Not Recommended', 'A minus', '5.7/10', '7', '3.0/4.0', '2.75/5', '3', 'B plus', '2.5/5.0', '63/100', '76/100', '55/100', '8.01/10', '18/20', '74/100', '2.75', '4.293382/10', '5.2/10', '1.75/4', '2', 'F- - -', '1/10', 'C -', '1.5 / 4', '2.2 / 5', '0.5/5', '7.5/20', '12/20', '1.5/4.0', '3 out 5', '3.5/10', '1.0/4.0', '2.5', '5.8/10', '89/100', '33/100', '71/100', '8.6/10', '5.4843853981/10', '8.9/10', 'C minus', '62/100', '3.25/5', '8.21/10', '3.5 / 5', '2.5/10', '0/10', '7.5', '2.0/5.0', '5.1/10', 'B minus', '88/100', '50/100', '4', '2.3/5', '64/100', '5/20', '2 Ripples', '3.7/10', '86/100', '1/6', '.5/5', 'FOUR STARS', '11/20', 'Recommended', '3.0/5', '8', '5.0/10', '1.0/4', '15/20', '7.6/10', 'short', 'high +2 out of -4..+4', '6.2/10', '61/100', 'high 0 out of -4..+4', '4.75/5', '9.9/10', '8.4/10', '6.25/10', 'FIVE STARS', '6/8', '+1 out of -4..+4', '4/6', '72/100', '7.2/10', 'B -', '16.5/20', '81/100', '8.75/10', '3.5/5.0', '75/100', "'3/4'", "'4/4'", '42/100', '59/100', '5.9/10', '80/100', '2. 5 / 5', '0 out of -4..+4', '9.3/10', '93/100', 'Low Half Price', '1.85/10', '38/100', '8.1/10', '6.9/10', 'D ', '2 / 5', '3/5 ', '12.5/20', '77/100', '6.0/10', '3.0/5.0', '1.75/5', 'B-plus', '8.65/10', '8.0/10', '7.21/10', '36/100', '2.0', '7.7/10', '21/100', '2.0/5', '79/100', '2/6', '73/100', '4.0/5.0', '2.50/5', '3.2/5', '5.0/5', '3.7/5', '49/100', '7.25/10', '3 / 5', '9.2/10', '14/20', '6.7/10', '9.174/10', '9.0/10', '8.8/10', '91/100', '67/100', '5.75/10', '1.9/5', '94/100', '13/20', '4 / 5', 'Catch It On Cable', '1.25/5', '4.0/10', '5.4/10', '17/20', '3.5 stars', '7.8/10', '7.1/10', '4.5/5.0', '5/5.0', '6.5', '82/100', '40/100', '4.9/10', '920', '3.6/5', '2.2/10', '2.25/4', '3.75/5', 'Highly Recommended', '66/100', '6', 'b+', '6.4/10', '4.25/5', '9.25/10', '8.3/10', '5', 'B-minus', '7.3/10', '2.25/5', '2.4/5', '4.12/10', '18.5/20', "'2'", '2.0/10', '***1/2', '37/100', '3.8/5', '69/100', '77', 'C plus', '20/20', '3 stars', '9/100', '9.66/10', "'2.5/4'", '1.0/5', '2.0/4', '.96/10', '2 stars', '2.7/10', 'Big Screen Watch', '9.0', '19/20', 'C +', '3.619125458/10', '6.3/10', 'low +2 out of -4..+4', '***', '6.1/10', '16/20', '7.95/10', '2.5/3', '1.5/5.0', '6.0000001/10', '6.1492458/10', '12/100', '7.65/10', '9.8/10', '5.5642243/10', '1.3/5', 'A+++', '3.8/4', '4/5 ', 'low 0 out of -4..+4', "'3.5/4'", '2.75/4', '57/100', '5.0/5.0', '4.7/10', '4 stars', '1/1', '16/100', "'2/4'", '7.15/10', '6 out of 10', 'b', '7.9/10', '96/100', '100', '9.002/10', '1.6/5', '3.3/5', 'b-', '95/100', '7.5/ 10', 'Fresh', '3.25/4', 'low +3 out of -4..+4', '47/100', 'c+', '31/100', '6.45/10', '51/100', '9.4/10', '3.4/4', '3/100', '5.5/20', 'A -', '84/100', '2.9/5', '4.2/5', '3 of 5', '7.83/10', '4.5 / 5', '1-5 stars', '53/100', '4.6/10', '8.2/10', 'B+ ', '43/100', 'low +1 out of -4..+4', '8.82438/10', '8.5', '9/20', '56/100', '6.95/10', '4.8/10', '8.89/10', '3.044316/10', 'B +', '4.8/5', '8.3/100', '9', '5.9821/10', 'capsule', '5.3/10', '8.5 out of 10', '2.3/10', '10/100', '9.42816572/10', '10', '2.00', '5.751/10', '9.188/10', '3.1/5', '2.2/5', '54/100', '6.01/10', '100/100', '4.21/10', '5 of 5', '3.9/5', '3.2', '3.8/10', '3.4/10', '8.39421/ ...

# %%
# Define conversion functions
def convert_star_rating(rating):
    try:
        num, denom = map(float, rating.split('/'))
        return round((num / denom) * 10, 2)
    except:
        return None

def convert_numeric_rating(rating):
    try:
        if '%' in rating:
            return round(float(rating.strip('%')) / 10, 2)
        else:
            return round(float(rating), 2)
    except:
        return None

def convert_alphabetic_rating(rating):
    grade_map = {
        'A+': 10, 'A': 9.5, 'A-': 9,
        'B+': 8.5, 'B': 8, 'B-': 7.5,
        'C+': 7, 'C': 6.5, 'C-': 6,
        'D+': 5.5, 'D': 5, 'D-': 4.5,
        'F': 0
    }
    return grade_map.get(rating.upper().strip(), None)

def convert_original_score(score):
    if isinstance(score, str):
        if '/' in score:
            return convert_star_rating(score)
        elif any(char.isdigit() for char in score):
            return convert_numeric_rating(score)
        else:
            return convert_alphabetic_rating(score)
    return None

# %%
combined_df['originalScore_normalized'] = combined_df['originalScore'].apply(convert_original_score)

# %%
combined_df = combined_df.dropna(subset=['originalScore_normalized'])

# %%
values_out_of_range = combined_df[(combined_df['originalScore_normalized'] < 0) | (combined_df['originalScore_normalized'] > 10)]

if values_out_of_range.empty:
    print("All values in originalScore_normalized are between 0 and 10.")
else:
    print("Some values in originalScore_normalized are out of the 0-10 range.")
    print(values_out_of_range)
# Out:
# Some values in originalScore_normalized are out of the 0-10 range.
#                                           id  \
# 968           the_man_who_killed_don_quixote
# 1425     what_to_expect_when_youre_expecting
# 18583                                sobibor
# 20947        dont_be_afraid_of_the_dark_2011
# 23113                              vikingdom
# ...                                      ...
# 1512477                          tower_heist
# 1515274                          grand_masti
# 1517059                            rush_2013
# 1538037                              vertigo
# 1540720                          young_adult
#
#                                         title  audienceScore  tomatoMeter  \
# 968            The Man Who Killed Don Quixote           60.0    66.000000
# 1425     What to Expect When You're Expecting           47.0    23.000000
# 18583                                 Sobibor           52.0    75.000000
# 20947             Don't Be Afraid of the Dark           34.0    61.000000
# 23113                               Vikingdom           24.0    43.000000
# ...                                       ...            ...          ...
# 1512477                           Tower Heist           48.0    67.000000
# 1515274                           Grand Masti           34.0    66.920339
# 1517059                                  Rush           88.0    88.000000
# 1538037                               Vertigo           93.0    92.000000
# 1540720                           Young Adult           49.0    80.000000
#
#           rating                                     ratingContents  \
# 968      Unknown                                            Unknown
# 1425       PG-13  ['Language', 'Crude and Sexual Content', 'Them...
# 18583    Unknown                                            Unknown
# 20947          R                             ['Violence', 'Terror']
# 23113    Unknown                                            Unknown
# ...          ...                                                ...
# 1512477    PG-13                     ['Sexual Content', 'Language']
# 1515274  Unknown                                            Unknown
# 1517059        R  ['Language', 'Brief Drug Use', 'Nudity', 'Sexu...
# 1538037  Unknown                                            Unknown
# 1540720        R                ['Some Sexual Content', 'Language']
#
#          runtimeMinutes                                genre originalLanguage  \
# 968               133.0                    Comedy, Adventure          English
# 1425              110.0               Comedy, Drama, Romance          English
# 18583             120.0                Drama, Biography, War          Russian
# 20947              99.0  Fantasy, Horror, Mystery & thriller          English
# 23113             110.0                    Adventure, Action          English
# ...                 ...                                  ...              ...
# 1512477           105.0                    Comedy, Adventure          English
# 1515274           137.0               Comedy, Drama, Romance            Hindi
# 1517059           123.0                        Drama, Action          English
# 1538037           128.0                   Mystery & thriller          English
# 1540720            94.0               Comedy, Drama, Romance          English
#
#                       director  \
# 968              Terry Gilliam
# 1425                Kirk Jones
# 18583    Konstantin Khabenskiy
# 20947               Troy Nixey
# 23113          Yusry Abd Halim
# ...                        ...
# 1512477           Brett Ratner
# 1515274            Indra Kumar
# 1517059             Ron Howard
# 1538037       Alfred Hitchcock
# 1540720          Jason Reitman
#
#                                                     writer  \
# 968                             Terry Gilliam,Tony Grisoni
# 1425                             Shauna Cross,Heather Hach
# 18583                                       Andrey Nazarov
# 20947                   Guillermo del Toro,Matthew Robbins
# 23113                                          James Coyne
# ...                                                    ...
# 1512477                         Ted Griffin,Jeff Nathanson
# 1515274                    Tushar Hiranandani,Milap Zaveri
# 1517059                                       Peter Morgan
# 1538037  Pierre Boileau,Thomas Narcejac,Samuel A. Taylo...
# 1540720                                        Diablo Cody
#
#                   distributor     reviewId originalScore  \
# 968        Screen Media Films    2574849.0         13.20
# 1425          Lionsgate Films    2085054.0         2.1/2
# 18583    Samuel Goldwyn Films    2581411.0           920
# 20947            FilmDistrict    2005971.0         2.1/2
# 23113                 Unknown    2169742.0            77
# ...                       ...          ...           ...
# 1512477    Universal Pictures    2022028.0         2.1/2
# 1515274               Unknown  102769320.0           -10
# 1517059    Universal Pictures    2166606.0         2.1/2
# 1538037    Paramount Pictures      20518.0         5.5/5
# 1540720    Paramount Pictures    2044468.0         2.1/2
#
#                                                 reviewText scoreSentiment  \
# 968                                 ...a fascinating mess.       POSITIVE
# 1425     I found some of its multiple storylines annoyi...       POSITIVE
# 18583    While the entire film has been downbeat (to sa...       POSITIVE
# 20947    The key decision in a film like this is how so...       POSITIVE
# 23113    Vikingdom is not a great movie, or even a very...       NEGATIVE
# ...                                                    ...            ...
# 1512477  I've seen great caper movies, and this isn't o...       NEGATIVE
# 1515274  There&#8217;s no better indication of our Grea...       NEGATIVE
# 1517059  Ron Howard has brought this story to life with...       POSITIVE
# 1538037  Vertigo stands as one of the thrill master's m...       POSITIVE
# 1540720  There is admittedly some slight novelty value ...       NEGATIVE
#
#          originalScore_normalized
# 968                          13.2
# 1425                         10.5
# 18583                       920.0
# 20947                        10.5
# 23113                        77.0
# ...                           ...
# 1512477                      10.5
# 1515274                     -10.0
# 1517059                      10.5
# 1538037                      11.0
# 1540720                      10.5
#
# [226 rows x 17 columns]

# %%
# Find rows with negative normalized scores and convert them to positive
negative_score_rows = combined_df[combined_df['originalScore_normalized'] < 0]

# %%
combined_df = combined_df.drop('originalScore', axis=1)

# %%
print(negative_score_rows)
# Out:
#                                    id                         title  \
# 890193                new_york_minute               New York Minute
# 1092138                 danny_the_dog                     Unleashed
# 1131363                      movie_43                      Movie 43
# 1481712  super_babies_baby_geniuses_2  SuperBabies: Baby Geniuses 2
# 1515274                   grand_masti                   Grand Masti
#
#          audienceScore  tomatoMeter   rating  \
# 890193            47.0    11.000000       PG
# 1092138           74.0    66.000000        R
# 1131363           24.0     4.000000        R
# 1481712           24.0     0.000000       PG
# 1515274           34.0    66.920339  Unknown
#
#                                             ratingContents  runtimeMinutes  \
# 890193            ['Thematic Elements', 'Mild Sensuality']            91.0
# 1092138  ['Nudity', 'Language', 'Some Sexuality', 'Stro...           102.0
# 1131363  ['Graphic Nudity', 'Dialogue', 'Language', 'So...            94.0
# 1481712             ['Some Rude Humor', 'Action/Violence']            88.0
# 1515274                                            Unknown           137.0
#
#                           genre originalLanguage  \
# 890193                   Comedy          English
# 1092138           Action, Drama          English
# 1131363                  Comedy          English
# 1481712   Kids & family, Comedy          English
# 1515274  Comedy, Drama, Romance            Hindi
#
#                                                   director  \
# 890193                                       Dennie Gordon
# 1092138                                    Louis Leterrier
# 1131363  Steven Brill,Peter Farrelly,Will Graham,Steve ...
# 1481712                                          Bob Clark
# 1515274                                        Indra Kumar
#
#                                                     writer  \
# 890193                                           Emily Fox
# 1092138                       Luc Besson,Robert Mark Kamen
# 1131363  Will Carlough,Tobias Carlson,Jacob Fleisher,Pa...
# 1481712                         Steven Paul,Gregory Poppen
# 1515274                    Tushar Hiranandani,Milap Zaveri
#
#                          distributor     reviewId originalScore  \
# 890193         Warner Bros. Pictures    1278036.0          -1/4
# 1092138               Focus Features    1391537.0          -1/4
# 1131363             Relativity Media    2126274.0         -1/10
# 1481712  Sony Pictures Entertainment    1313346.0          -1/4
# 1515274                      Unknown  102769320.0           -10
#
#                                                 reviewText scoreSentiment  \
# 890193   When Bob Saget is the best thing you have goin...       NEGATIVE
# 1092138  Unleashed is one of those truly cursed movies ...       NEGATIVE
# 1131363  A black mark on the careers of everyone involv...       NEGATIVE
# 1481712  Talking babies are just creepy. I kept waiting...       NEGATIVE
# 1515274  There&#8217;s no better indication of our Grea...       NEGATIVE
#
#          originalScore_normalized
# 890193                       -2.5
# 1092138                      -2.5
# 1131363                      -1.0
# 1481712                      -2.5
# 1515274                     -10.0

# %%
combined_df.loc[negative_score_rows.index, 'originalScore_normalized'] = negative_score_rows['originalScore_normalized'].abs()

# %%
combined_df.loc[1515274]
# Out:
# id                                                                grand_masti
# title                                                             Grand Masti
# audienceScore                                                            34.0
# tomatoMeter                                                         66.920339
# rating                                                                Unknown
# ratingContents                                                        Unknown
# runtimeMinutes                                                          137.0
# genre                                                  Comedy, Drama, Romance
# originalLanguage                                                        Hindi
# director                                                          Indra Kumar
# writer                                        Tushar Hiranandani,Milap Zaveri
# distributor                                                           Unknown
# reviewId                                                          102769320.0
# reviewText                  There&#8217;s no better indication of our Grea...
# scoreSentiment                                                       NEGATIVE
# originalScore_normalized                                                 10.0
# Name: 1515274, dtype: object

# %%
combined_df.loc[combined_df.index == 1515274, 'scoreSentiment'] = 'POSITIVE'

# %%
print(combined_df.loc[1515274][['originalScore_normalized', 'scoreSentiment']])
# Out:
# originalScore_normalized        10.0
# scoreSentiment              POSITIVE
# Name: 1515274, dtype: object

# %%
# Ensure all values are within the 0-10 range
combined_df['originalScore_normalized'] = combined_df['originalScore_normalized'].apply(lambda x: min(x, 10) if x is not None else None)
combined_df['originalScore_normalized'] = combined_df['originalScore_normalized'].apply(lambda x: max(x, 0) if x is not None else None)

# %%
combined_df.describe()
# Out:
#        audienceScore    tomatoMeter  runtimeMinutes      reviewId  \
# count  993876.000000  993876.000000   993876.000000  9.938760e+05
# mean       64.811362      65.726166      107.159153  8.244274e+06
# std        19.325149      25.710327       20.426512  2.446752e+07
# min         0.000000       0.000000        2.000000  1.000000e+00
# 25%        51.000000      48.000000       94.000000  1.525052e+06
# 50%        67.000000      71.000000      104.000000  2.121500e+06
# 75%        81.000000      88.000000      117.000000  2.532073e+06
# max       100.000000     100.000000     1013.000000  1.027962e+08
#
#        originalScore_normalized
# count             993876.000000
# mean                   6.540351
# std                    2.042376
# min                    0.000000
# 25%                    5.000000
# 50%                    7.000000
# 75%                    8.000000
# max                   10.000000

# %%
combined_df.head()
# Out:
#              id       title  audienceScore  tomatoMeter   rating  \
# 2     love_lies  Love, Lies           43.0    66.920339  Unknown
# 3     love_lies  Love, Lies           43.0    66.920339  Unknown
# 6   adrift_2018      Adrift           65.0    69.000000    PG-13
# 8   adrift_2018      Adrift           65.0    69.000000    PG-13
# 10  adrift_2018      Adrift           65.0    69.000000    PG-13
#
#                                        ratingContents  runtimeMinutes  \
# 2                                             Unknown           120.0
# 3                                             Unknown           120.0
# 6   ['Injury Images', 'Brief Drug Use', 'Thematic ...           120.0
# 8   ['Injury Images', 'Brief Drug Use', 'Thematic ...           120.0
# 10  ['Injury Images', 'Brief Drug Use', 'Thematic ...           120.0
#
#                         genre originalLanguage                       director  \
# 2                       Drama           Korean  Park Heung-Sik,Heung-Sik Park
# 3                       Drama           Korean  Park Heung-Sik,Heung-Sik Park
# 6   Adventure, Drama, Romance          English              Baltasar Kormákur
# 8   Adventure, Drama, Romance          English              Baltasar Kormákur
# 10  Adventure, Drama, Romance          English              Baltasar Kormákur
#
#                                               writer distributor     reviewId  \
# 2             Ha Young-Joon,Jeon Yun-su,Song Hye-jin     Unknown    2739073.0
# 3             Ha Young-Joon,Jeon Yun-su,Song Hye-jin     Unknown    2333658.0
# 6   Aaron Kandell,Jordan Kandell,David Branson Smith   STX Films  102694850.0
# 8   Aaron Kandell,Jordan Kandell,David Branson Smith   STX Films    2816011.0
# 10  Aaron Kandell,Jordan Kandell,David Branson Smith   STX Films    2772153.0
#
#                                            reviewText scoreSentiment  \
# 2   Though let down by its routine love triangle n...       POSITIVE
# 3   While not perfect, Love, Lies is a worthy disc...       POSITIVE
# 6   This is nowhere near the level of other great ...       POSITIVE
# 8   For almost the entire runtime, the only people...       NEGATIVE
# 10  What is meant to be a voyage of self-discovery...       NEGATIVE
#
#     originalScore_normalized
# 2                        8.0
# 3                        7.0
# 6                        6.0
# 8                        7.0
# 10                       4.0

# %%
#save combined_df into csv

combined_df.to_csv("/content/drive/MyDrive/MCA_project/Final/combined_cleaned.csv", index=False)
